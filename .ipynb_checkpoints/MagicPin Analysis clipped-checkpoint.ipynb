# %%
import pandas as pd
import numpy as np

# %matplotlib inline
from matplotlib import pyplot as plt

import seaborn as sns
sns.set()

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)

from scipy import stats
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df = pd.read_csv('magicpin_assignment.csv', encoding='latin-1')

# %% [markdown]
# Different encoding

# %%
df.head()
# Out:
#         ID  customer_id  merchant_id                         merchant_name  \
# 0  4181262      1078061       239907                       Barbeque Nation
# 1  4181263       800436       303261                     Jayshree Pure Veg
# 2  4181265       985816       224635  Pabrai's Fresh & Naturelle Ice Cream
# 3  4181266      1079912       156356             Vivo The Designer Couture
# 4  4181267       984371       215283                         Frozen Bottle
#
#    trxn_locality     home_locality   work_locality        date      time  \
# 0  Kalyani Nagar  B.T. Kawade Road  Santacruz West  2017-11-01  00:00:02
# 1  Kalyani Nagar     Kalyani Nagar      Malad East  2017-11-01  00:00:13
# 2    Koramangala         Jayanagar       Jayanagar  2017-11-01  00:00:32
# 3  Paschim Vihar            Narela          Narela  2017-11-01  00:00:34
# 4            HSR               HSR             HSR  2017-11-01  00:00:39
#
#    first transaction?  funding trxn?  bill size  cashback  followers
# 0                   1              0     4989.0      75.0       2997
# 1                   1              0      413.0      21.0       9070
# 2                   0              0      210.0      17.0       9420
# 3                   0              0     3295.0      10.0       5326
# 4                   0              0      638.4      40.0       6423

# %%
df.describe()
# Out:
#                  ID   customer_id    merchant_id  first transaction?  \
# count  4.461300e+05  4.461300e+05  446130.000000       446130.000000
# mean   4.520097e+06  7.991744e+05  134925.672999            0.103667
# std    1.954116e+05  3.288252e+05  108523.420754            0.304829
# min    4.181262e+06  2.400000e+01     456.000000            0.000000
# 25%    4.351085e+06  5.581520e+05   16264.000000            0.000000
# 50%    4.521134e+06  9.142660e+05   97259.000000            0.000000
# 75%    4.689602e+06  1.080513e+06  241167.000000            0.000000
# max    4.861247e+06  1.192475e+06  407529.000000            1.000000
#
#        funding trxn?      bill size       cashback      followers
# count  446130.000000  446130.000000  446129.000000  446130.000000
# mean        0.071203     829.117140      30.758163    5000.373102
# std         0.257165    2068.983404      34.383632    2886.266996
# min         0.000000       6.000000       0.000000       1.000000
# 25%         0.000000     189.000000      10.000000    2500.000000
# 50%         0.000000     382.000000      23.000000    5004.000000
# 75%         0.000000     805.000000      43.000000    7499.000000
# max         1.000000  453285.000000     475.000000   10000.000000

# %% [markdown]
# - Only about 7% of the transactions provided a cut to MagicPin
# - All bill amounts are entertained, ranging from Rs. 6 to Rs. 4,53,285
# - Cashback provided (mean Rs. 30) does not have much standard deviation. Max cashback is Rs. 475, which is meagre when compared to the bill sizes
# - The most popular profile(s) has/have 10,000 followers

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 446130 entries, 0 to 446129
# Data columns (total 14 columns):
# ID                    446130 non-null int64
# customer_id           446130 non-null int64
# merchant_id           446130 non-null int64
# merchant_name         446130 non-null object
# trxn_locality         446130 non-null object
# home_locality         446130 non-null object
# work_locality         446130 non-null object
# date                  446130 non-null object
# time                  446130 non-null object
# first transaction?    446130 non-null int64
# funding trxn?         446130 non-null int64
# bill size             446130 non-null float64
# cashback              446129 non-null float64
# followers             446130 non-null int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 47.7+ MB

# %% [markdown]
# All but one value are non null. Let's explore the null value row

# %%
df[df.isnull().any(axis=1)]
# Out:
#              ID  customer_id  merchant_id           merchant_name  \
# 301039  4659959       167666        88320  Cafe Coffee Day, IFFCO
#
#        trxn_locality home_locality work_locality        date      time  \
# 301039     Sector 28    Ardee City     Sector 29  2017-11-21  18:07:20
#
#         first transaction?  funding trxn?  bill size  cashback  followers
# 301039                   0              0   346489.0       NaN       1523

# %% [markdown]
# Spending Rs. 3,46,489 at CCD seems to be a data collection error, or an extremely enthusiastic coffee drinker. Let's take a look at the bill size and cashback distributions to ascertain

# %%
f, ax = plt.subplots(2, 1, figsize=(16, 10))
sns.distplot(df['bill size'], hist=False, ax=ax[0])
sns.distplot(df['cashback'].dropna(), hist=False, ax=ax[1])

# %% [markdown]
# Distribution is very tail-heavy

# %%
f, ax = plt.subplots(2, 1, figsize=(16, 10))
sns.boxplot(df['bill size'], ax=ax[0])
sns.boxplot(df['cashback'].dropna(), ax=ax[1])

# %% [markdown]
# There are a large amount of outliers, which will have to be removed. First, let us remove the row with Null value in cashback

# %%
df.dropna(inplace=True)

# %%
zscore = stats.zscore(df[['bill size', 'cashback']])

# %%
# https://stackoverflow.com/questions/23199796/detect-and-exclude-outliers-in-pandas-dataframe
df_clipped = df[(np.abs(zscore) < 3).all(axis=1)]

# %% [markdown]
# Let's look at the distributions again

# %%
f, ax = plt.subplots(2, 1, figsize=(16, 10))
sns.distplot(df_clipped['bill size'], hist=False, ax=ax[0])
sns.distplot(df_clipped['cashback'].dropna(), hist=False, ax=ax[1])

# %%
f, ax = plt.subplots(2, 1, figsize=(16, 10))
sns.boxplot(df_clipped['bill size'], ax=ax[0])
sns.boxplot(df_clipped['cashback'].dropna(), ax=ax[1])

# %%
merchant_count_df = pd.DataFrame(df_clipped['merchant_name'].value_counts()).reset_index()

# %%
merchant_count_df
# Out:
#                                       index  merchant_name
# 0                                McDonald's          20181
# 1                            Domino's Pizza          18422
# 2                                       KFC          11834
# 3                               Burger King          11418
# 4                                    Subway           6285
# 5                                Haldiram's           5621
# 6                                Big Bazaar           4990
# 7                                 Pizza Hut           3993
# 8                           Cafe Coffee Day           2931
# 9                                     Dmart           2805
# 10                              Bikanervala           2791
# 11                           Reliance Fresh           2642
# 12                            Brand Factory           2131
# 13                                    DMart           2108
# 14                                  Easyday           1887
# 15                           Dunkin' Donuts           1809
# 16                       Om Sweets & Snacks           1528
# 17                            Shoppers Stop           1510
# 18                           More Megastore           1352
# 19                                Keventers           1248
# 20                                Starbucks           1203
# 21                          Reliance Trends           1136
# 22                                Lifestyle           1117
# 23                                      Max           1074
# 24                          The Burger Club            974
# 25                                  Chaayos            961
# 26                                Om Sweets            960
# 27                 McDonald's, Udupi Garden            950
# 28                        Natural Ice Cream            949
# 29                              Hira Sweets            919
# ...                                     ...            ...
# 30781                       Sunrise Incense              1
# 30782                  Udupi Veg Restaurant              1
# 30783                    Barbeque & Biryani              1
# 30784                     Mitthu Tikki Wala              1
# 30785                         Choice Liquor              1
# 30786                            Anna Maria              1
# 30787                     Tekchand Tiloomal              1
# 30788           My Style Ladies & Kids Wear              1
# 30789         Pure Pulses Depatmental Store              1
# 30790                      Udupi Coffee Bar              1
# 30791                      The Silver Brush              1
# 30792              Supper Hero's Food Truck              1
# 30793                                 Zaiqa              1
# 30794                      Gold Line Breadz              1
# 30795                         Grover Bakery              1
# 30796                 Pinball Thermal Store              1
# 30797                       HR24 Restaurant              1
# 30798                     Sadguru Ice Cream              1
# 30799  Studio Lounge - Hotel Studio Estique              1
# 30800                       SGR Enterprises              1
# 30801                        Subway, Panvel              1
# 30802  Hyderabadi Biryani and Kebabs Corner              1
# 30803                               Madaari              1
# 30804                         Slice 'n' Joy              1
# 30805                                 Deepa              1
# 30806                     Rajashree Designs              1
# 30807               Libas Designer Boutique              1
# 30808             Benzy's Family Restaurant              1
# 30809                             Good Luck              1
# 30810         Zolocrust - Hotel Clarks Amer              1
#
# [30811 rows x 2 columns]

# %%
f, ax = plt.subplots(figsize=(16, 10))
sns.barplot(x='index', y='merchant_name', data=merchant_count_df[:50])
plt.xticks(rotation=45, ha='right')
ax.set_xlabel('Merchant Name')
ax.set_ylabel('Count')
ax.set_title('Most popular merchants (Top 50)')
# Out:
# Text(0.5,1,'Most popular merchants (Top 50)')

# %% [markdown]
# - McDonald's is the most popular merchant on the platform, followed by Domino's, KFC and Burger King. This is as expected
# - Some regional/local vendors are also present in the list

# %% [markdown]
# Let's look at the distribution of cashbacks offered by Top 10 merchants

# %%
df_top_10 = pd.merge(merchant_count_df[:10], df_clipped, left_on='index', right_on='merchant_name', how='left')

# %%
df_top_10.drop(columns=['merchant_name_x', 'index'], inplace=True)
df_top_10.rename(index=str, columns={'merchant_name_y': 'merchant_name'}, inplace=True)

# %%
f, ax = plt.subplots(figsize=(16, 10))
sns.boxplot(x='merchant_name', y='cashback', data=df_top_10, hue='first transaction?', ax=ax)

# %%
f, ax = plt.subplots(figsize=(16, 10))
sns.boxplot(x='merchant_name', y='cashback', data=df_top_10, hue='funding trxn?', ax=ax)

# %% [markdown]
# - Most merchants do not seem to favour first-timers, since mean and even IQR of the cashbacks are comparable
# - Funding merchants are favoured by offering much larger cashbacks
# - Is the cashback only dependant on first/n-timer transaction? Probably not
#
# Let's check correlation

# %%
sns.pairplot(df_clipped.loc[:, ['first transaction?', 'funding trxn?', 'bill size', 'cashback', 'followers']])

# %% [markdown]
# Some conjectures we can arrive at from the above
# 1. Cashback amount does not depend on bill size (cashback vs bill size)
# 2. Popular people do not spend more and also do not get relatively higher cashbacks. One may be the cause of the other (bill size vs followers, cashback vs followers)
# 3. People of all amounts of followers seem to be equally distributed (followers)

# %%
df_clipped[(df_clipped['first transaction?']==1) & (df_clipped['followers'] > 0)].shape[0]
# Out:
# 45472

# %% [markdown]
# 45,472 people had 1 or more followers even before they made their first transaction! Talk about popularity.
#
# Let's take a look at potential outliers. Listing all trxns $\ge$ Rs. 5,000

# %%
df_clipped[df_clipped['bill size'] >= 5000].sort_values(['bill size', 'cashback'], ascending=False)
# Out:
#              ID  customer_id  merchant_id                    merchant_name  \
# 160726  4425371       103804       157139                      Blackberrys
# 140473  4395399        68087       108260                    Brand Factory
# 112783  4352981      1107756       176500                         Pa Pa ya
# 70936   4288189      1032104       235408                      Green Field
# 326810  4677776       231771       108260                    Brand Factory
# 307454  4648321      1073617        58788        AB's - Absolute Barbecues
# 326832  4677813       444268       108260                    Brand Factory
# 307132  4647796      1073792       177256  3B's - Buddies, Bar & Barbecues
# 307436  4648295      1073618       177256  3B's - Buddies, Bar & Barbecues
# 416546  4812966      1145765       200156               Dhaba By Claridges
# 364947  4735235      1004106       169869                  Sara Silk Store
# 333451  4687927       623617        74525                  Barbeque Nation
# 172687  4442513      1104333       157416                     Central Jail
# 45123   4250307       695977       108201          Brand Factory, Sector 3
# 2182    4184939       490467       176919                    Brand Factory
# 162658  4428204       378152        97232               Koramangala Social
# 350791  4713794      1088020       175625                    Brand Factory
# 149843  4409102       539183         1337       My Bar Lounge & Restaurant
# 58008   4269338      1094534       270411                            Metro
# 257843  4572928      1027730       157140          Big Bazaar, Sahara Mall
# 342680  4701967       359028        81281                The Smoke Factory
# 217227  4512062       414901       110202                    Kuberan Silks
# 68563   4284622       776391       258971                            Metro
# 383287  4762388      1037056       199404                    Brand Factory
# 272990  4595593      1127900        89542                       McDonald's
# 255273  4569185       945699       261749                 Vishal Mega Mart
# 119952  4363919       522122        89093                             Slug
# 379828  4757294      1175533       193226                        Lifestyle
# 379843  4757318       653429       193226                        Lifestyle
# 311965  4655088      1075701       234335               Roopali Restaurant
# ...         ...          ...          ...                              ...
# 172391  4442080      1083489        14041                   Blue Moustache
# 376501  4752406       946972        86999                        Lifestyle
# 380534  4758322       580402       162242                        Lifestyle
# 42847   4246997       917030       144255                   Vicky Garments
# 58002   4269331      1058031       108661                          Central
# 60434   4272881       501513        54076                      Jawed Habib
# 121481  4366735       917030       144255                   Vicky Garments
# 266537  4586115      1148496       108816                             Puma
# 273488  4596321         2806        83741                          Bindals
# 295012  4629136       644994       177810                Natural Ice Cream
# 313087  4656865      1128425       194615                 Payal Collection
# 323835  4673243       701922       315185                     Utsav sarees
# 415246  4810947      1155296         1541                   Otik Cake Shop
# 60298   4272689      1092010        64857                     Stars Parade
# 70959   4288230      1097042       114278    Pure Play, Liverpool Fc Store
# 77683   4298498      1085897       275983             Marudhara Collection
# 129117  4378352      1061345       252522          Reliance Trends-Fashion
# 173845  4444533       738696        14041                   Blue Moustache
# 187194  4465171      1074604        73893                      Royal Dawat
# 239290  4545648      1082025       296849                    Body Line Gym
# 293071  4625898       771586        53915                   Domino's Pizza
# 301974  4639927      1095897       189356                         Payal Nx
# 302677  4640985      1128487       189356                         Payal Nx
# 326737  4677661      1164012       240355                   Domino's Pizza
# 380699  4758546      1175108       180538                    Magicc Mirror
# 390213  4772296      1049511       103395                       Ahuja Sons
# 399954  4787540      1110788       305853                     Cafe Zam Zam
# 400617  4788530      1180441        65577                  Brijwasi Sweets
# 406094  4796733      1180254       172564                 Krishna Fashions
# 419234  4817345      1091238        54337                            Tadka
#
#                trxn_locality         home_locality             work_locality  \
# 160726             Sector 14             Sector 17        Old Rajinder Nagar
# 140473             Sahibabad           Laxmi Nagar            Maharaja Nagar
# 112783                 Saket         Malviya Nagar             Malviya Nagar
# 70936           Sinhgad Road           Khadakwasla               Khadakwasla
# 326810             Sahibabad             Sector 50                Sector 127
# 307454                   BTM           Koramangala                 Jayanagar
# 326832             Sahibabad             Sector 17               Udyog Vihar
# 307132                   BTM           Koramangala             Sarjapur Road
# 307436                   BTM             Anandapur                 Anandapur
# 416546           Indiranagar               Adugodi                    Domlur
# 364947          Lavelle Road          Basavanagudi             Co-orporation
# 333451       Electronic City       Electronic City           Electronic City
# 172687             Jayanagar             Jayanagar                 Jayanagar
# 45123                 Rohini        Prashant Vihar                 Sector 46
# 2182            Marathahalli              KR Puram                  KR Puram
# 162658           Koramangala    Basaveshwara Nagar              Malleshwaram
# 350791          Banashankari  Rajarajeshwari Nagar      Rajarajeshwari Nagar
# 149843  Connaught Place (CP)          Adarsh Nagar  Qutab Institutional Area
# 58008        Electronic City       Electronic City           Electronic City
# 257843               MG Road             Sector 43              Sainik Farms
# 342680             Sector 38             Sector 17                 Sector 29
# 217227              Majestic        Sahakara Nagar                 Jayanagar
# 68563               Shahdara              Shahdara                  Shahdara
# 383287              Vikhroli                 Powai            Ghatkopar East
# 272990            Whitefield          Gandhi Nagar                Whitefield
# 255273                   BTM                   HSR                       HSR
# 119952              Nagawara             Sector 20                  Horamavu
# 379828           Lower Parel            Grant Road                   Girgaon
# 379843           Lower Parel                Tardeo                     Marol
# 311965               FC Road          Sassoon Road                   FC Road
# ...                      ...                   ...                       ...
# 172391           Koramangala     Bannerghatta Road                Triplicane
# 376501             Sector 18              Sector 2         Parliament Street
# 380534         Richmond Road                Ulsoor               Indiranagar
# 42847            Uttam Nagar           Uttam Nagar               Uttam Nagar
# 58002              Bellandur          Marathahalli              Marathahalli
# 60434              Sector 38   Mayur Vihar Phase 1               Jamia Nagar
# 121481           Uttam Nagar           Uttam Nagar               Uttam Nagar
# 266537                   BTM           Brookefield               Brookefield
# 273488  Connaught Place (CP)           Gole Market               Rajiv Chowk
# 295012        Mumbai Central            Grant Road                Grant Road
# 313087          Marine Lines             Bhayandar                 Bhayandar
# 323835           Sector 10 A           Sector 10 A               Sector 10 A
# 415246        Rajouri Garden        Rajouri Garden                 Sector 61
# 60298                Chembur               Chembur                   Chembur
# 70959            Mohan Nagar           Mohan Nagar               Mohan Nagar
# 77683                  Warje                 Warje                     Warje
# 129117         Borivali West           Lower Parel               Lower Parel
# 173845           Koramangala             Gopalbari               Jama Masjid
# 187194              Zirakpur             Sector 15                 Sector 15
# 239290              Sector 5               Khanpur                   Khanpur
# 293071          Malleshwaram               Adugodi                   Adugodi
# 301974             Kalbadevi             Kalbadevi                 Kalbadevi
# 302677             Kalbadevi             Bhayandar                 Bhayandar
# 326737               Attapur              Gandipet                  Gandipet
# 380699        Ghatkopar East        Ghatkopar East            Ghatkopar West
# 390213           Sector 21 C           Ballabhgarh                  Sector 7
# 399954               Chembur               Chembur                   Chembur
# 400617        Ghatkopar West        Ghatkopar West            Ghatkopar West
# 406094            Nagarbhavi            Nagarbhavi        Kumaraswamy Layout
# 419234          Adarsh Nagar         Jawahar Nagar             Jawahar Nagar
#
#               date      time  first transaction?  funding trxn?  bill size  \
# 160726  2017-11-12  16:58:59                   0              0    6835.00
# 140473  2017-11-11  15:34:44                   0              0    6835.00
# 112783  2017-11-09  16:48:20                   1              0    6834.00
# 70936   2017-11-06  01:36:36                   0              0    6832.00
# 326810  2017-11-23  15:26:39                   0              0    6830.44
# 307454  2017-11-21  23:39:09                   0              0    6830.00
# 326832  2017-11-23  15:28:07                   0              0    6830.00
# 307132  2017-11-21  23:00:05                   0              0    6830.00
# 307436  2017-11-21  23:36:46                   0              0    6830.00
# 416546  2017-11-28  21:20:48                   0              0    6829.00
# 364947  2017-11-25  19:46:01                   1              0    6827.00
# 333451  2017-11-23  21:11:10                   0              0    6826.00
# 172687  2017-11-12  23:18:34                   0              0    6826.00
# 45123   2017-11-04  18:28:58                   0              0    6825.00
# 2182    2017-11-01  13:54:59                   0              0    6824.48
# 162658  2017-11-12  18:11:08                   0              0    6824.00
# 350791  2017-11-24  22:14:08                   0              0    6823.00
# 149843  2017-11-11  21:23:17                   0              0    6822.00
# 58008   2017-11-05  15:58:33                   1              0    6821.00
# 257843  2017-11-18  22:15:43                   0              0    6821.00
# 342680  2017-11-24  16:53:15                   0              1    6820.00
# 217227  2017-11-16  16:46:34                   0              0    6820.00
# 68563   2017-11-05  21:53:59                   0              0    6819.00
# 383287  2017-11-26  19:01:35                   0              0    6817.00
# 272990  2017-11-19  19:35:46                   0              1    6815.00
# 255273  2017-11-18  21:00:15                   0              0    6815.00
# 119952  2017-11-09  22:54:24                   0              0    6812.00
# 379828  2017-11-26  16:29:46                   1              0    6811.00
# 379843  2017-11-26  16:30:06                   0              0    6811.00
# 311965  2017-11-22  15:12:00                   0              0    6809.00
# ...            ...       ...                 ...            ...        ...
# 172391  2017-11-12  23:00:17                   0              1    5000.00
# 376501  2017-11-26  14:28:34                   0              0    5000.00
# 380534  2017-11-26  17:01:06                   0              0    5000.00
# 42847   2017-11-04  16:38:28                   0              0    5000.00
# 58002   2017-11-05  15:58:19                   0              0    5000.00
# 60434   2017-11-05  17:39:29                   0              0    5000.00
# 121481  2017-11-10  12:25:14                   0              0    5000.00
# 266537  2017-11-19  15:58:51                   0              0    5000.00
# 273488  2017-11-19  19:48:42                   0              0    5000.00
# 295012  2017-11-21  11:47:46                   0              0    5000.00
# 313087  2017-11-22  16:14:00                   0              0    5000.00
# 323835  2017-11-23  12:25:10                   0              0    5000.00
# 415246  2017-11-28  20:26:02                   0              0    5000.00
# 60298   2017-11-05  17:34:07                   0              0    5000.00
# 70959   2017-11-06  02:38:47                   1              0    5000.00
# 77683   2017-11-06  18:58:56                   0              0    5000.00
# 129117  2017-11-10  19:24:19                   0              0    5000.00
# 173845  2017-11-13  11:31:56                   0              0    5000.00
# 187194  2017-11-14  13:33:13                   0              0    5000.00
# 239290  2017-11-17  22:37:10                   0              0    5000.00
# 293071  2017-11-20  22:20:27                   0              0    5000.00
# 301974  2017-11-21  18:59:40                   0              0    5000.00
# 302677  2017-11-21  19:33:08                   0              0    5000.00
# 326737  2017-11-23  15:21:38                   1              0    5000.00
# 380699  2017-11-26  17:13:19                   1              0    5000.00
# 390213  2017-11-26  21:48:54                   0              0    5000.00
# 399954  2017-11-27  18:51:22                   1              0    5000.00
# 400617  2017-11-27  19:24:33                   1              0    5000.00
# 406094  2017-11-28  08:36:44                   0              0    5000.00
# 419234  2017-11-29  09:41:20                   0              0    5000.00
#
#         cashback  followers
# 160726      85.0       4377
# 140473      50.0        770
# 112783      95.0        426
# 70936       50.0       9663
# 326810      25.0       8659
# 307454      95.0       3293
# 326832      95.0       2272
# 307132      80.0        342
# 307436      10.0       6088
# 416546      80.0        176
# 364947      85.0       9615
# 333451      95.0       8491
# 172687      25.0       7067
# 45123       25.0       2030
# 2182        50.0       9374
# 162658      95.0        931
# 350791      25.0       8091
# 149843      25.0       6469
# 58008       30.0        219
# 257843      10.0       3035
# 342680     100.0       9331
# 217227      95.0       6683
# 68563       30.0       6126
# 383287      25.0       3763
# 272990      75.0       1249
# 255273      30.0       9805
# 119952      75.0       9774
# 379828      80.0        821
# 379843      25.0       2272
# 311965      40.0       9180
# ...          ...        ...
# 172391      25.0       5376
# 376501      25.0       9405
# 380534      25.0       9039
# 42847       10.0       4244
# 58002       10.0       5610
# 60434       10.0       4600
# 121481      10.0       1165
# 266537      10.0       4533
# 273488      10.0       8010
# 295012      10.0       9450
# 313087      10.0       3241
# 323835      10.0       9972
# 415246      10.0       5561
# 60298        5.0       5991
# 70959        5.0       8802
# 77683        5.0       4421
# 129117       5.0       7307
# 173845       5.0       4054
# 187194       5.0       8188
# 239290       5.0       1945
# 293071       5.0       5886
# 301974       5.0       4331
# 302677       5.0       3679
# 326737       5.0        191
# 380699       5.0       2692
# 390213       5.0       2244
# 399954       5.0       8974
# 400617       5.0       1069
# 406094       5.0       5978
# 419234       5.0       2940
#
# [4207 rows x 14 columns]

# %% [markdown]
# The z-score elimination method suggested that all transactions above Rs. 7,000 were outliers. Thus, these transactions were removed.
#
# The largest bill prize goes to customer 103804 at **Blackberrys for Rs.6,835**. This is a mens' fashion brand. The customer immediately recieved a **cashback of Rs.85**.
#
# Another contender for the highest bill amount spent was at **Pa Pa Ya for Rs. 6,834**. Pa Pa Ya is a thai restaurant. **Rs. 95 was recieved as cashback**.
#
# It seems that people tend to spend more on food and clothing. Is the amount of cashback provided becoming the reason for non-returning customers? Let's find out

# %%
set_of_first_customers = df_clipped[df_clipped['first transaction?']==1]['customer_id']

print(set_of_first_customers.unique().shape[0])
print(set_of_first_customers.shape[0])
# Out:
# 45469
# 45472

# %% [markdown]
# 3 customers seem to be recorded twice

# %%
set_of_first_customers[set_of_first_customers.duplicated()]
# Out:
# 88704     1102010
# 96806     1101987
# 296376    1149507
# Name: customer_id, dtype: int64

# %% [markdown]
# Some customers seem to have made multiple first transactions. Let's take a quick detour to look at them

# %%
df_clipped[df_clipped['customer_id'] == 1102010]
# Out:
#              ID  customer_id  merchant_id        merchant_name trxn_locality  \
# 88621   4315390      1102010       270601  Navratna Shop 4 All   Uttam Nagar
# 88704   4315512      1102010       292738           Shop 4 All   Uttam Nagar
# 178984  4452348      1102010       292738           Shop 4 All   Uttam Nagar
# 179033  4452417      1102010       270601  Navratna Shop 4 All   Uttam Nagar
#
#        home_locality work_locality        date      time  first transaction?  \
# 88621    Uttam Nagar     Sector 23  2017-11-07  17:51:37                   1
# 88704    Uttam Nagar     Sector 23  2017-11-07  17:56:47                   1
# 178984   Uttam Nagar     Sector 23  2017-11-13  17:50:38                   0
# 179033   Uttam Nagar     Sector 23  2017-11-13  17:53:14                   0
#
#         funding trxn?  bill size  cashback  followers
# 88621               0       35.0      18.0       3013
# 88704               0      809.0      30.0       7337
# 178984              0      697.0      30.0       7010
# 179033              0       35.0      18.0        776

# %% [markdown]
# This looks a bit suspicious. The person made a transaction at 17:51 on 7<sup>th</sup> and then again 5 minutes later, and both registered as first transactions. Shop was same too, but second name used is a variation of the first.
#
# A point worth noting is that the person also gained 4,324 followers in 5 minutes! Something must be wrong. Was the person demonstrating (possibly to a large audience) a potential security breach that he/she found in the app?

# %%
df_clipped[df_clipped['customer_id'] == 1101987]
# Out:
#              ID  customer_id  merchant_id        merchant_name trxn_locality  \
# 88526   4315246      1101987       270601  Navratna Shop 4 All   Uttam Nagar
# 96806   4328014      1101987         2172       Domino's Pizza   Uttam Nagar
# 100647  4333891      1101987         4954    Rajinder Da Dhaba    Safdarjung
#
#        home_locality work_locality        date      time  first transaction?  \
# 88526    Uttam Nagar   Uttam Nagar  2017-11-07  17:44:45                   1
# 96806    Uttam Nagar   Uttam Nagar  2017-11-08  14:06:43                   1
# 100647   Uttam Nagar   Uttam Nagar  2017-11-08  17:49:34                   0
#
#         funding trxn?  bill size  cashback  followers
# 88526               0       35.0      18.0       3423
# 96806               0      221.0      15.0       3535
# 100647              0      418.0      50.0       5211

# %% [markdown]
# Uttam Nagar seems to be a glitchy locality, particularly 'Navratna Shop 4 All'. Second bill sizes have been consistently bigger till now, as compared to the first bill

# %%
df_clipped[df_clipped['customer_id'] == 1149507]
# Out:
#              ID  customer_id  merchant_id merchant_name         trxn_locality  \
# 274049  4597149      1149507        89368  Shake Eat Up  Netaji Subhash Place
# 296376  4631317      1149507        89368  Shake Eat Up  Netaji Subhash Place
# 302218  4640307      1149507       134831      Net Wear           Kamla Nagar
#
#          home_locality   work_locality        date      time  \
# 274049  Prashant Vihar  Prashant Vihar  2017-11-19  20:03:44
# 296376  Prashant Vihar  Prashant Vihar  2017-11-21  13:45:03
# 302218  Prashant Vihar  Prashant Vihar  2017-11-21  19:12:07
#
#         first transaction?  funding trxn?  bill size  cashback  followers
# 274049                   1              1      218.0      33.0        934
# 296376                   1              1      114.0      17.0        502
# 302218                   0              0      506.0      45.0       6700

# %% [markdown]
# This customer defies the trend we have been seeing. Second bill size was smaller and followers reduced in the second transaction.
#
# But then the customer gained 6,198 followers in ~5.5 hours. Is this amount of change normal?

# %%
# Assumption
# Returning customers would also have a record where first transaction = 1
set_of_returning_customers = df_clipped[df_clipped['first transaction?'] == 0]['customer_id']

# %%
regular_or_returning_customers = set(set_of_returning_customers) - set(set_of_first_customers)

# %%
len(regular_or_returning_customers)
# Out:
# 68263

# %%
lost_customers = set(set_of_first_customers) - set(set_of_returning_customers)

# %%
len(lost_customers)
# Out:
# 23702

# %% [markdown]
# 23,702 customers never went beyond the first transaction (atleast in the month of November). I am willing to say that low cashback amounts are a part, if not a major part, of the cause of leaving customers
#
# What is the transaction trend by date?

# %%
df_by_date = df_clipped.groupby('date', as_index=False)['bill size'].sum()

# %%
f, ax = plt.subplots(figsize=(16, 10))
plt.xticks(rotation=45, ha='right')
sns.lineplot(x='date', y='bill size', data=df_by_date, ax=ax)

# %% [markdown]
# 1<sup>st</sup> November was a Wednesday. Thus, we can see that the consumer spending cycle has a very nice weekly trend. Transactions peak on weekends and fall on Monday. Then they gain momentum till the weekend.
#
# November 19<sup>th</sup> (Sunday) saw the highest net transaction amount of Rs. 1.60+ crore
#
# What is the hourly trend?

# %%
df_clipped['mod_time'] = df_clipped['time'].apply(lambda x: ':'.join(x.split(':')[:-1]))
# Out:
# d:\work\.dl-env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_by_minute = df_clipped.groupby('mod_time', as_index=False)['bill size'].sum()
df_by_minute['mod_time'] = pd.to_datetime(df_by_minute['mod_time'], format='%H:%M').dt.time

# %%
f, ax = plt.subplots(figsize=(16, 10))
plt.xticks(rotation=90, ha='right')
sns.lineplot(x='mod_time', y='bill size', data=df_by_minute, ax=ax)

# %% [markdown]
# - Daily cycle begins gaining momentum at around 13:00 and increases through 15:00 (probably lunchtime).
# - Then it falls till about 17:00 and starts gaining again and peaks around 21:30-22:00 (probably dinnertime).
# - The cycle falls again, and progresses towards the next day
#
# Let's track the most active customers

# %%
df_active_customers = pd.DataFrame(df_clipped['customer_id'].value_counts()).reset_index().sort_values('customer_id', ascending=False)

# %%
df_active_customers
# Out:
#           index  customer_id
# 0        220524          135
# 1       1130580          129
# 2       1063810          122
# 3        778430          120
# 4       1057113          113
# 5        724058          113
# 6        708590          112
# 7        994954          107
# 8        326678          107
# 9        963326          103
# 10       524932          100
# 11       705701           98
# 12       825703           96
# 13       114833           91
# 14      1136339           89
# 15       912696           87
# 17      1008322           86
# 16      1031548           86
# 18       800016           84
# 19      1067088           83
# 20        20178           82
# 21       973084           82
# 22       685655           81
# 23       833452           81
# 24      1055371           80
# 25       558523           79
# 28       510063           78
# 29       588705           78
# 27       792261           78
# 26       689493           78
# ...         ...          ...
# 83674    495679            1
# 83675   1022014            1
# 83676   1030202            1
# 83677    816706            1
# 83678   1142497            1
# 83679   1140448            1
# 83680   1087198            1
# 83662   1081821            1
# 83660   1024313            1
# 83640    800842            1
# 83649    989742            1
# 83641    280644            1
# 83642    995627            1
# 83643   1040689            1
# 83644   1091545            1
# 83645   1171953            1
# 83646    789068            1
# 83647    807495            1
# 83648   1186605            1
# 83650    993832            1
# 83659   1114605            1
# 83651   1002020            1
# 83652    956958            1
# 83653    408074            1
# 83654    102911            1
# 83655   1147389            1
# 83656   1159675            1
# 83657    643575            1
# 83658   1176051            1
# 113731  1165127            1
#
# [113732 rows x 2 columns]

# %%
f, ax = plt.subplots(figsize=(16, 10))
sns.barplot(x='index', y='customer_id', data=df_active_customers[:50])
plt.xticks(rotation=90)
ax.set_xlabel('Customer ID')
ax.set_ylabel('Trxns')
plt.title('50 most active customers')
# Out:
# Text(0.5,1,'50 most active customers')

# %% [markdown]
# Customer 220524 is our most active November customer with 135 trxns. Customer 1130580 is not far behind with 129 November trxns. Let's look at some of their trxns

# %%
df_clipped[df_clipped['customer_id'] == 220524]
# Out:
#              ID  customer_id  merchant_id                   merchant_name  \
# 430     4182101       220524        89645        Cut & Style, Huda Market
# 1520    4183928       220524         2224                  Domino's Pizza
# 1556    4183977       220524         2310                       Pizza Hut
# 1668    4184154       220524       303912       Modern Super Market Sec 6
# 9436    4195891       220524       113793                 Gurgaon Central
# 11653   4199210       220524        54021          Om Restaurant & Sweets
# 16359   4206818       220524       291761                  Reliance Fresh
# 22493   4216301       220524       228483              Om Sweets & Snacks
# 27007   4223486       220524        53610                    Burger Point
# 27181   4223754       220524        13150                       Om Sweets
# 28105   4225075       220524       292673                  Reliance Fresh
# 30669   4228969       220524       161821         More Mega Store-Fashion
# 31780   4230610       220524       256491      Dreamcann Foods, Sector 51
# 33145   4232635       220524         7938                          Subway
# 39156   4241750       220524        53617                      Haldiram's
# 45908   4251481       220524       256136             Go Gourment, Fortis
# 54280   4263796       220524       282403                         Easyday
# 59167   4271009       220524       161821         More Mega Store-Fashion
# 59221   4271093       220524        10003                       Raj Foods
# 60555   4273054       220524        53617                      Haldiram's
# 60596   4273121       220524        80319           The Mind Cafe, Fortis
# 61017   4273744       220524        60314                  Baskin Robbins
# 62578   4276078       220524        89298         Burger King, HUDA Metro
# 63210   4277007       220524         5960              Southy, HUDA Metro
# 63627   4277604       220524         2221      Domino's Pizza, HUDA Metro
# 64111   4278316       220524        15959          Chai Point, HUDA Metro
# 64276   4278529       220524         1046     Eggers Madhouse, HUDA Metro
# 64358   4278659       220524        70220          McDonald's, HUDA Metro
# 64479   4278828       220524        10164         Fruit Inbox, HUDA Metro
# 64827   4279308       220524        99118  The Chocolate Room, Huda Metro
# ...         ...          ...          ...                             ...
# 271562  4593545       220524        89298         Burger King, HUDA Metro
# 272035  4594211       220524        12374      Dunkin' Donuts, HUDA Metro
# 272161  4594388       220524         5926                   Chicago Pizza
# 272204  4594453       220524         8999        Kung Fu Chow, HUDA Metro
# 272383  4594729       220524        15402             Giani's, HUDA Metro
# 273984  4597054       220524        99118  The Chocolate Room, Huda Metro
# 274026  4597117       220524       256507                       Wow! Momo
# 274129  4597250       220524        60407                  Subway, Fortis
# 274340  4597564       220524        70220          McDonald's, HUDA Metro
# 274497  4597790       220524       177400                  Drunken Monkey
# 282918  4610450       220524       161821         More Mega Store-Fashion
# 286513  4616066       220524        10003                       Raj Foods
# 315946  4661269       220524       264990                  Reliance Fresh
# 356581  4722659       220524       228483              Om Sweets & Snacks
# 357241  4723631       220524        89298         Burger King, HUDA Metro
# 357436  4723931       220524        97301    Wraps Cafe, Huda City Center
# 357506  4724040       220524        70220          McDonald's, HUDA Metro
# 358268  4725193       220524        53617                      Haldiram's
# 358397  4725362       220524       261698                       Keventers
# 382729  4761550       220524        15959          Chai Point, HUDA Metro
# 383122  4762121       220524         2221      Domino's Pizza, HUDA Metro
# 383450  4762621       220524        89298         Burger King, HUDA Metro
# 383673  4762942       220524        70220          McDonald's, HUDA Metro
# 383967  4763388       220524        12374      Dunkin' Donuts, HUDA Metro
# 388250  4769500       220524       228483              Om Sweets & Snacks
# 393967  4778232       220524       161821         More Mega Store-Fashion
# 400094  4787750       220524         2224                  Domino's Pizza
# 400173  4787866       220524         2310                       Pizza Hut
# 414103  4809159       220524         2224                  Domino's Pizza
# 414294  4809453       220524        54021          Om Restaurant & Sweets
#
#        trxn_locality home_locality work_locality        date      time  \
# 430        Sector 10     Sector 10   Sector 10 A  2017-11-01  10:11:42
# 1520      Sector 10A     Sector 10   Sector 10 A  2017-11-01  13:10:56
# 1556      Sector 10A     Sector 10   Sector 10 A  2017-11-01  13:13:11
# 1668          Dwarka     Sector 10   Sector 10 A  2017-11-01  13:22:07
# 9436         MG Road     Sector 10   Sector 10 A  2017-11-01  20:48:24
# 11653      Sector 10     Sector 10   Sector 10 A  2017-11-01  22:32:30
# 16359       Sector 4     Sector 10   Sector 10 A  2017-11-02  15:58:21
# 22493       Sector 8     Sector 10   Sector 10 A  2017-11-02  22:02:50
# 27007       Sector 7     Sector 10   Sector 10 A  2017-11-03  14:54:05
# 27181      Sector 14     Sector 10   Sector 10 A  2017-11-03  15:02:56
# 28105      Sector 31     Sector 10   Sector 10 A  2017-11-03  15:51:14
# 30669     Sohna Road     Sector 10   Sector 10 A  2017-11-03  18:35:04
# 31780      Sector 57     Sector 10   Sector 10 A  2017-11-03  19:36:03
# 33145      Sector 14     Sector 10   Sector 10 A  2017-11-03  20:38:42
# 39156      Sector 29     Sector 10   Sector 10 A  2017-11-04  13:47:01
# 45908      Sector 44     Sector 10   Sector 10 A  2017-11-04  19:05:35
# 54280      GTB Nagar     Sector 10   Sector 10 A  2017-11-05  13:15:45
# 59167     Sohna Road     Sector 10   Sector 10 A  2017-11-05  16:47:46
# 59221      Sector 15     Sector 10   Sector 10 A  2017-11-05  16:50:22
# 60555      Sector 29     Sector 10   Sector 10 A  2017-11-05  17:43:48
# 60596      Sector 44     Sector 10   Sector 10 A  2017-11-05  17:45:18
# 61017      Sector 53     Sector 10   Sector 10 A  2017-11-05  18:01:20
# 62578      Sector 29     Sector 10   Sector 10 A  2017-11-05  18:58:58
# 63210      Sector 29     Sector 10   Sector 10 A  2017-11-05  19:18:56
# 63627      Sector 29     Sector 10   Sector 10 A  2017-11-05  19:32:50
# 64111      Sector 29     Sector 10   Sector 10 A  2017-11-05  19:49:20
# 64276      Sector 29     Sector 10   Sector 10 A  2017-11-05  19:53:28
# 64358      Sector 29     Sector 10   Sector 10 A  2017-11-05  19:56:14
# 64479      Sector 29     Sector 10   Sector 10 A  2017-11-05  19:59:48
# 64827      Sector 29     Sector 10   Sector 10 A  2017-11-05  20:09:54
# ...              ...           ...           ...         ...       ...
# 271562     Sector 29     Sector 10   Sector 10 A  2017-11-19  18:57:02
# 272035     Sector 29     Sector 10   Sector 10 A  2017-11-19  19:10:41
# 272161   DLF Phase 4     Sector 10   Sector 10 A  2017-11-19  19:14:03
# 272204     Sector 29     Sector 10   Sector 10 A  2017-11-19  19:15:14
# 272383     Sector 29     Sector 10   Sector 10 A  2017-11-19  19:20:18
# 273984     Sector 29     Sector 10   Sector 10 A  2017-11-19  20:02:04
# 274026     Sector 29     Sector 10   Sector 10 A  2017-11-19  20:03:09
# 274129     Sector 45     Sector 10   Sector 10 A  2017-11-19  20:05:17
# 274340     Sector 29     Sector 10   Sector 10 A  2017-11-19  20:10:11
# 274497     Sector 29     Sector 10   Sector 10 A  2017-11-19  20:14:18
# 282918    Sohna Road     Sector 10   Sector 10 A  2017-11-20  13:15:51
# 286513     Sector 15     Sector 10   Sector 10 A  2017-11-20  16:51:36
# 315946     Sector 15     Sector 10   Sector 10 A  2017-11-22  18:50:45
# 356581      Sector 8     Sector 10   Sector 10 A  2017-11-25  14:27:58
# 357241     Sector 29     Sector 10   Sector 10 A  2017-11-25  14:51:59
# 357436     Sector 29     Sector 10   Sector 10 A  2017-11-25  14:59:59
# 357506     Sector 29     Sector 10   Sector 10 A  2017-11-25  15:02:29
# 358268     Sector 29     Sector 10   Sector 10 A  2017-11-25  15:34:09
# 358397     Sector 44     Sector 10   Sector 10 A  2017-11-25  15:38:27
# 382729     Sector 29     Sector 10   Sector 10 A  2017-11-26  18:45:10
# 383122     Sector 29     Sector 10   Sector 10 A  2017-11-26  18:56:58
# 383450     Sector 29     Sector 10   Sector 10 A  2017-11-26  19:05:51
# 383673     Sector 29     Sector 10   Sector 10 A  2017-11-26  19:11:53
# 383967     Sector 29     Sector 10   Sector 10 A  2017-11-26  19:19:56
# 388250      Sector 8     Sector 10   Sector 10 A  2017-11-26  21:03:15
# 393967    Sohna Road     Sector 10   Sector 10 A  2017-11-27  12:12:28
# 400094    Sector 10A     Sector 10   Sector 10 A  2017-11-27  18:58:57
# 400173    Sector 10A     Sector 10   Sector 10 A  2017-11-27  19:03:00
# 414103    Sector 10A     Sector 10   Sector 10 A  2017-11-28  19:35:24
# 414294     Sector 10     Sector 10   Sector 10 A  2017-11-28  19:44:02
#
#         first transaction?  funding trxn?  bill size  cashback  followers  \
# 430                      0              0       70.0       5.0        347
# 1520                     0              0      139.0      10.0        830
# 1556                     0              0      446.0       9.0       7289
# 1668                     0              0      245.0       5.0       4950
# 9436                     0              0     2826.0      25.0          7
# 11653                    0              0       40.0       3.0         84
# 16359                    0              0      639.0      25.0       6126
# 22493                    0              0      210.0      21.0       2874
# 27007                    0              0       35.0       5.0       4405
# 27181                    0              0      195.0      50.0       4114
# 28105                    0              0      970.0      30.0       7065
# 30669                    0              0     1222.0      40.0       1066
# 31780                    0              0      276.0      41.0       5807
# 33145                    0              0      330.0      33.0       9043
# 39156                    0              0      189.0      26.0       2092
# 45908                    0              0      194.0      29.0       2342
# 54280                    0              0     1220.0      30.0       7896
# 59167                    0              0      700.0      40.0       8360
# 59221                    0              0      655.0      66.0       3503
# 60555                    0              0      135.0      14.0       2498
# 60596                    0              0      149.0      15.0       1201
# 61017                    0              0      264.0      26.0       8028
# 62578                    0              0      240.0      36.0       3349
# 63210                    0              0      130.0      20.0       5667
# 63627                    0              0      292.0      44.0       5909
# 64111                    0              0       59.0       9.0       7539
# 64276                    0              1      165.0      41.0       7198
# 64358                    0              0      316.0      40.0       8531
# 64479                    0              0      483.0      10.0       1759
# 64827                    0              0      298.0      45.0       9015
# ...                    ...            ...        ...       ...        ...
# 271562                   0              0      494.0      30.0       3335
# 272035                   0              0      314.0      31.0        812
# 272161                   0              0      145.0      15.0       6448
# 272204                   0              0      209.0       4.0        576
# 272383                   0              0      435.0      40.0       7729
# 273984                   0              0      318.0      32.0       7166
# 274026                   0              0      147.0      15.0       3576
# 274129                   0              0      300.0      30.0        728
# 274340                   0              0      105.0      11.0       3580
# 274497                   0              1      188.0       2.0       9519
# 282918                   0              0      127.0      10.0       1422
# 286513                   0              0      895.0      75.0       7778
# 315946                   0              0       19.0       1.0       9855
# 356581                   0              0      116.0      50.0       1889
# 357241                   0              0      311.0      50.0       6089
# 357436                   0              1      130.0      10.0       3336
# 357506                   0              0      243.0      50.0       9455
# 358268                   0              0      237.0      24.0       2474
# 358397                   0              0      163.0      16.0       8876
# 382729                   0              0       76.0       8.0       1942
# 383122                   0              0      186.0      50.0       6467
# 383450                   0              0      239.0      24.0       1476
# 383673                   0              0      877.0      50.0       9859
# 383967                   0              0       72.0      50.0       1775
# 388250                   0              0      420.0      42.0       9144
# 393967                   0              0     1498.0      40.0       1920
# 400094                   0              0      153.0      31.0       8874
# 400173                   0              0      404.0       8.0       2879
# 414103                   0              0      120.0      24.0       7795
# 414294                   0              0      101.0      20.0       7984
#
#        mod_time
# 430       10:11
# 1520      13:10
# 1556      13:13
# 1668      13:22
# 9436      20:48
# 11653     22:32
# 16359     15:58
# 22493     22:02
# 27007     14:54
# 27181     15:02
# 28105     15:51
# 30669     18:35
# 31780     19:36
# 33145     20:38
# 39156     13:47
# 45908     19:05
# 54280     13:15
# 59167     16:47
# 59221     16:50
# 60555     17:43
# 60596     17:45
# 61017     18:01
# 62578     18:58
# 63210     19:18
# 63627     19:32
# 64111     19:49
# 64276     19:53
# 64358     19:56
# 64479     19:59
# 64827     20:09
# ...         ...
# 271562    18:57
# 272035    19:10
# 272161    19:14
# 272204    19:15
# 272383    19:20
# 273984    20:02
# 274026    20:03
# 274129    20:05
# 274340    20:10
# 274497    20:14
# 282918    13:15
# 286513    16:51
# 315946    18:50
# 356581    14:27
# 357241    14:51
# 357436    14:59
# 357506    15:02
# 358268    15:34
# 358397    15:38
# 382729    18:45
# 383122    18:56
# 383450    19:05
# 383673    19:11
# 383967    19:19
# 388250    21:03
# 393967    12:12
# 400094    18:58
# 400173    19:03
# 414103    19:35
# 414294    19:44
#
# [135 rows x 15 columns]

# %% [markdown]
# A lot of this customer's trxns are in and around Fortis, a hospital in Gurgaon (HUDA Metro, Fortis, ...). This seems to imply that either the customer is an employee of the hospital or was an attendant to someone who was admitted in Fortis throughout a large part of November

# %%
df_clipped[df_clipped['customer_id'] == 1130580]
# Out:
#              ID  customer_id  merchant_id                 merchant_name  \
# 197020  4480128      1130580       244905              Hotel Sri Balaji
# 197448  4480761      1130580       240723             Natural Ice Cream
# 212859  4505268      1130580       240263                    McDonald's
# 213060  4505625      1130580       240438              Akson Restaurant
# 214053  4507137      1130580       242338  Cafe Coffee Day - The Lounge
# 214619  4508001      1130580       250973                      Paradise
# 216601  4511029      1130580       240540                Karachi Bakery
# 217770  4512929      1130580       240420                     Pizza Hut
# 219234  4515279      1130580       240268     Sarvi Bakers & Restaurant
# 220961  4517928      1130580       240300                      Blue Fox
# 221814  4519239      1130580       241202              Sarvi Restaurant
# 222953  4520959      1130580       251197                     Angaara 5
# 223870  4522378      1130580       241402                    Sarvi Cafe
# 224015  4522601      1130580       243202                        Subway
# 224269  4523012      1130580       240414           Rayalaseema Ruchulu
# 227353  4527962      1130580       240540                Karachi Bakery
# 229793  4531534      1130580       241402                    Sarvi Cafe
# 232273  4535353      1130580       241042    Ohri's Ruci & Idoni Bistro
# 233860  4537756      1130580       241826       Sri Balaji Family Dhaba
# 235537  4540263      1130580       240278               Santosh Banjara
# 237044  4542390      1130580       240310           Kritunga Restaurant
# 237575  4543155      1130580       240765             10 Downing Street
# 238219  4544066      1130580       240268     Sarvi Bakers & Restaurant
# 239628  4546119      1130580       241342            Hotel Sitara Grand
# 239933  4546573      1130580       241202              Sarvi Restaurant
# 242390  4550555      1130580       243528                         Dhaba
# 244312  4553430      1130580       241025     Rajdhani Thali Restaurant
# 252059  4564624      1130580       240285                         Tabla
# 254650  4568268      1130580       240278               Santosh Banjara
# 255916  4570120      1130580       240770                  The Clay Pot
# ...         ...          ...          ...                           ...
# 370692  4743480      1130580       241198                    The Dhabha
# 374418  4749264      1130580       241198                    The Dhabha
# 374962  4750042      1130580       244323           Thalimpu Restaurant
# 375886  4751504      1130580       242054                  Almond House
# 385205  4765170      1130580       251197                     Angaara 5
# 386379  4766792      1130580       243906                     Shubavsar
# 389452  4771221      1130580       240524                   Cream Stone
# 395424  4780485      1130580       242954              Eagle Boys Pizza
# 398630  4785432      1130580       240540                Karachi Bakery
# 399923  4787488      1130580       240263                    McDonald's
# 401719  4790101      1130580       240273                   Bikanervala
# 402723  4791533      1130580       240268     Sarvi Bakers & Restaurant
# 403478  4792600      1130580       240264                      Chutneys
# 404024  4793411      1130580       240723             Natural Ice Cream
# 404565  4794237      1130580       251179                   Burger King
# 407448  4798794      1130580       240378              Chinese Pavilion
# 407674  4799141      1130580       240268     Sarvi Bakers & Restaurant
# 408134  4799826      1130580       251099                    Guilt Trip
# 408508  4800397      1130580       243320        The ThickShake Factory
# 412015  4805910      1130580       240273                   Bikanervala
# 413515  4808292      1130580       241402                    Sarvi Cafe
# 414494  4809764      1130580       240438              Akson Restaurant
# 415311  4811045      1130580       241171                      Paradise
# 416878  4813465      1130580       241202              Sarvi Restaurant
# 417722  4814736      1130580       244005    Shree Santosh Family Dhaba
# 418544  4816061      1130580       240337                        Subway
# 437090  4846504      1130580       244130  New Cafe Niloufer Restaurant
# 443266  4856568      1130580       243840                      Chicha's
# 444099  4857889      1130580       251197                     Angaara 5
# 445086  4859426      1130580       241202              Sarvi Restaurant
#
#           trxn_locality home_locality work_locality        date      time  \
# 197020      Khairatabad    Masab Tank    Panjagutta  2017-11-14  22:05:50
# 197448  Srinagar Colony    Masab Tank    Panjagutta  2017-11-14  22:27:34
# 212859    Banjara Hills    Masab Tank    Panjagutta  2017-11-16  12:16:04
# 213060       Panjagutta    Masab Tank    Panjagutta  2017-11-16  12:42:42
# 214053    Banjara Hills    Masab Tank    Panjagutta  2017-11-16  13:48:48
# 214619       Masab Tank    Masab Tank    Panjagutta  2017-11-16  14:18:03
# 216601    Banjara Hills    Masab Tank    Panjagutta  2017-11-16  16:05:25
# 217770    Banjara Hills    Masab Tank    Panjagutta  2017-11-16  17:22:14
# 219234    Banjara Hills    Masab Tank    Panjagutta  2017-11-16  18:54:55
# 220961    Banjara Hills    Masab Tank    Panjagutta  2017-11-16  20:16:40
# 221814    Banjara Hills    Masab Tank    Panjagutta  2017-11-16  20:53:09
# 222953    Banjara Hills    Masab Tank    Panjagutta  2017-11-16  21:39:34
# 223870    Banjara Hills    Masab Tank    Panjagutta  2017-11-16  22:22:03
# 224015    Banjara Hills    Masab Tank    Panjagutta  2017-11-16  22:29:32
# 224269       Lakdikapul    Masab Tank    Panjagutta  2017-11-16  22:44:12
# 227353    Banjara Hills    Masab Tank    Panjagutta  2017-11-17  13:47:24
# 229793    Banjara Hills    Masab Tank    Panjagutta  2017-11-17  15:29:18
# 232273    Banjara Hills    Masab Tank    Panjagutta  2017-11-17  17:48:14
# 233860   Padmarao Nagar    Masab Tank    Panjagutta  2017-11-17  19:09:12
# 235537    Banjara Hills    Masab Tank    Panjagutta  2017-11-17  20:19:25
# 237044       Panjagutta    Masab Tank    Panjagutta  2017-11-17  21:11:10
# 237575         Begumpet    Masab Tank    Panjagutta  2017-11-17  21:30:57
# 238219    Banjara Hills    Masab Tank    Panjagutta  2017-11-17  21:53:09
# 239628    Banjara Hills    Masab Tank    Panjagutta  2017-11-17  22:52:28
# 239933    Banjara Hills    Masab Tank    Panjagutta  2017-11-17  23:11:28
# 242390    Banjara Hills    Masab Tank    Panjagutta  2017-11-18  13:03:37
# 244312    Banjara Hills    Masab Tank    Panjagutta  2017-11-18  14:35:09
# 252059    Banjara Hills    Masab Tank    Panjagutta  2017-11-18  19:32:01
# 254650    Banjara Hills    Masab Tank    Panjagutta  2017-11-18  20:43:51
# 255916    Banjara Hills    Masab Tank    Panjagutta  2017-11-18  21:17:08
# ...                 ...           ...           ...         ...       ...
# 370692    Banjara Hills    Masab Tank    Panjagutta  2017-11-25  22:29:25
# 374418    Banjara Hills    Masab Tank    Panjagutta  2017-11-26  12:44:50
# 374962         Ameerpet    Masab Tank    Panjagutta  2017-11-26  13:15:17
# 375886    Banjara Hills    Masab Tank    Panjagutta  2017-11-26  14:04:05
# 385205    Banjara Hills    Masab Tank    Panjagutta  2017-11-26  19:52:15
# 386379    Banjara Hills    Masab Tank    Panjagutta  2017-11-26  20:20:38
# 389452    Banjara Hills    Masab Tank    Panjagutta  2017-11-26  21:29:35
# 395424    Banjara Hills    Masab Tank    Panjagutta  2017-11-27  14:02:06
# 398630    Banjara Hills    Masab Tank    Panjagutta  2017-11-27  17:27:09
# 399923    Banjara Hills    Masab Tank    Panjagutta  2017-11-27  18:49:16
# 401719    Banjara Hills    Masab Tank    Panjagutta  2017-11-27  20:11:35
# 402723    Banjara Hills    Masab Tank    Panjagutta  2017-11-27  20:50:29
# 403478    Banjara Hills    Masab Tank    Panjagutta  2017-11-27  21:21:20
# 404024  Srinagar Colony    Masab Tank    Panjagutta  2017-11-27  21:44:38
# 404565    Banjara Hills    Masab Tank    Panjagutta  2017-11-27  22:08:54
# 407448    Banjara Hills    Masab Tank    Panjagutta  2017-11-28  13:05:47
# 407674    Banjara Hills    Masab Tank    Panjagutta  2017-11-28  13:23:41
# 408134    Banjara Hills    Masab Tank    Panjagutta  2017-11-28  13:50:49
# 408508    Banjara Hills    Masab Tank    Panjagutta  2017-11-28  14:09:56
# 412015    Banjara Hills    Masab Tank    Panjagutta  2017-11-28  17:37:18
# 413515    Banjara Hills    Masab Tank    Panjagutta  2017-11-28  19:08:06
# 414494       Panjagutta    Masab Tank    Panjagutta  2017-11-28  19:53:15
# 415311    Necklace Road    Masab Tank    Panjagutta  2017-11-28  20:28:40
# 416878    Banjara Hills    Masab Tank    Panjagutta  2017-11-28  21:34:44
# 417722   Himayath Nagar    Masab Tank    Panjagutta  2017-11-28  22:14:38
# 418544    Banjara Hills    Masab Tank    Panjagutta  2017-11-28  23:17:45
# 437090       Lakdikapul    Masab Tank    Panjagutta  2017-11-30  15:53:00
# 443266       Masab Tank    Masab Tank    Panjagutta  2017-11-30  21:09:38
# 444099    Banjara Hills    Masab Tank    Panjagutta  2017-11-30  21:41:22
# 445086    Banjara Hills    Masab Tank    Panjagutta  2017-11-30  22:23:03
#
#         first transaction?  funding trxn?  bill size  cashback  followers  \
# 197020                   0              0      383.0      27.0       4261
# 197448                   1              0      300.0      15.0       7547
# 212859                   0              0      219.0       5.0       5209
# 213060                   0              0      415.0      21.0        721
# 214053                   0              0      400.0       5.0       5799
# 214619                   0              0      425.0      21.0       3349
# 216601                   0              0       90.0       5.0       2841
# 217770                   0              0      651.0      40.0       4015
# 219234                   0              0      645.0      32.0        543
# 220961                   0              0      761.0      50.0       4304
# 221814                   0              0      462.0      23.0       7649
# 222953                   0              0      724.0      30.0       4754
# 223870                   0              0      265.0      13.0       6698
# 224015                   0              0      361.0      18.0       3120
# 224269                   0              0      382.0      19.0       3382
# 227353                   0              0      330.0      17.0       6593
# 229793                   0              0      357.0      18.0       5537
# 232273                   0              0      583.0      30.0       7716
# 233860                   0              0      667.0      30.0        731
# 235537                   0              0      462.0      23.0       5345
# 237044                   0              0      242.0      12.0       7419
# 237575                   0              0      290.0       6.0        579
# 238219                   0              0      452.0      23.0       1569
# 239628                   0              0      315.0      32.0        565
# 239933                   0              0      708.0      35.0       7477
# 242390                   0              0      633.0      40.0       3203
# 244312                   0              0     1039.0      30.0       4847
# 252059                   0              0     1250.0      50.0       6024
# 254650                   0              0      688.0      30.0       8199
# 255916                   0              0      576.0      29.0       8785
# ...                    ...            ...        ...       ...        ...
# 370692                   0              0      529.0      50.0       1870
# 374418                   0              0      331.0      33.0       5663
# 374962                   0              0      710.0      10.0       9934
# 375886                   0              0      650.0      50.0        483
# 385205                   0              0      200.0       4.0       2408
# 386379                   0              0      872.0      50.0       7554
# 389452                   0              0      331.0       7.0       7633
# 395424                   0              0      517.0      10.0       1875
# 398630                   0              0      340.0      34.0       7604
# 399923                   0              0      309.0       6.0       6219
# 401719                   0              0     1135.0      10.0       2545
# 402723                   0              0      636.0      10.0       5369
# 403478                   0              0      460.0       9.0       5593
# 404024                   0              0      550.0      10.0       4919
# 404565                   0              0      375.0       5.0       2909
# 407448                   0              0      305.0      15.0       8756
# 407674                   0              0      420.0       8.0       2143
# 408134                   0              0      274.0       5.0       3347
# 408508                   0              0      334.0      17.0       9673
# 412015                   0              0      399.0       8.0       1274
# 413515                   0              0      368.0       7.0       4219
# 414494                   0              0      451.0       9.0       9355
# 415311                   0              0      644.0      32.0        361
# 416878                   0              0      766.0      10.0       8601
# 417722                   0              0      241.0      12.0       8933
# 418544                   0              0      529.0      10.0        151
# 437090                   0              0      300.0      15.0       4058
# 443266                   0              0      387.0       8.0       5200
# 444099                   0              0      388.0       8.0       3206
# 445086                   0              0      420.0       8.0       8119
#
#        mod_time
# 197020    22:05
# 197448    22:27
# 212859    12:16
# 213060    12:42
# 214053    13:48
# 214619    14:18
# 216601    16:05
# 217770    17:22
# 219234    18:54
# 220961    20:16
# 221814    20:53
# 222953    21:39
# 223870    22:22
# 224015    22:29
# 224269    22:44
# 227353    13:47
# 229793    15:29
# 232273    17:48
# 233860    19:09
# 235537    20:19
# 237044    21:11
# 237575    21:30
# 238219    21:53
# 239628    22:52
# 239933    23:11
# 242390    13:03
# 244312    14:35
# 252059    19:32
# 254650    20:43
# 255916    21:17
# ...         ...
# 370692    22:29
# 374418    12:44
# 374962    13:15
# 375886    14:04
# 385205    19:52
# 386379    20:20
# 389452    21:29
# 395424    14:02
# 398630    17:27
# 399923    18:49
# 401719    20:11
# 402723    20:50
# 403478    21:21
# 404024    21:44
# 404565    22:08
# 407448    13:05
# 407674    13:23
# 408134    13:50
# 408508    14:09
# 412015    17:37
# 413515    19:08
# 414494    19:53
# 415311    20:28
# 416878    21:34
# 417722    22:14
# 418544    23:17
# 437090    15:53
# 443266    21:09
# 444099    21:41
# 445086    22:23
#
# [129 rows x 15 columns]

# %% [markdown]
# The fact that the first transaction is not actually chronologically first is confusing
